# %%
import numpy as np
import matplotlib #hago esto asi para poder usar ginput en jupyter, cosa que parece que no era trivial
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importo archivos
#
# Tiene que haber una forma menos fea de hacer esto, después me gustaría buscarla. Tuve que:
# - Pasar todos los archivos a txt que aparentemente para numpy es mas facil que csv, eso creo que rinde mas en dataframes.
# - Borrar la última línea, que era mas fácil hacerlo a mano que con código aparentemente.

# %%
argon_170 = np.loadtxt('Datos dia 1/argon_170.txt',skiprows=33)
argon_20_cerca = np.loadtxt('Datos dia 1/argon_20ms_cerca.txt',skiprows=33)
argon_450 = np.loadtxt('Datos dia 1/argon_450.txt',skiprows=33)
fondo_003 = np.loadtxt('Datos dia 1/fondo_0.03.txt',skiprows=33)
fondo_200 = np.loadtxt('Datos dia 1/fondo_200ms.txt',skiprows=33)
fondo_20 = np.loadtxt('Datos dia 1/fondo_20ms.txt',skiprows=33)
fondo_30 = np.loadtxt('Datos dia 1/fondo_30ms.txt',skiprows=33)
fondo_luzapagada = np.loadtxt('Datos dia 1/fondo_luzapagada.txt',skiprows=33)
helio_075 = np.loadtxt('Datos dia 1/helio_0.75ms.txt',skiprows=33)
helio_30 = np.loadtxt('Datos dia 1/helio_30ms.txt',skiprows=33)
incog_30 = np.loadtxt('Datos dia 1/incog_3ms.txt',skiprows=33)
incog_3 = np.loadtxt('Datos dia 1/incog_30ms.txt',skiprows=33)
kripton_200 = np.loadtxt('Datos dia 1/kripton_30ms.txt',skiprows=33)
kripton_30 = np.loadtxt('Datos dia 1/kripton_200ms.txt',skiprows=33)
mercurio_120 = np.loadtxt('Datos dia 1/mercurio_120ms.txt',skiprows=33)
mercurio_300 = np.loadtxt('Datos dia 1/mercurio_300ms.txt',skiprows=33)
neon_08 = np.loadtxt('Datos dia 1/neon_0.8ms.txt',skiprows=33)
neon_5 = np.loadtxt('Datos dia 1/neon_5ms.txt',skiprows=33)
sodio_003 = np.loadtxt('Datos dia 1/sodio_0.03ms.txt',skiprows=33)
sodio_3 = np.loadtxt('Datos dia 1/sodio_3ms.txt',skiprows=33)
#sodio_5 = np.loadtxt('Datos dia 1/sodio_5ms.txt',skiprows=33)

# %%
x = argon_170[:,0]
y = argon_170[:,1]

#pruebo con uno, esto tira una figura afuera de un tamaño considerablemente grande, quizas se puede ir ajustando la región para cada uno, para tener mas precision
#por ejemplo a este se le podría pedir de graficarlo solo a partir de 600 algo

plt.figure(figsize=(15,8))
plt.plot(x,y)
lineas = plt.ginput(3)
print("clicked", x)
plt.show()
# Out:
# clicked [ 196.0870056  196.2940979  196.5012054 ... 1019.740417  1019.984558
#  1020.22876  ]
